# %%
import sys

# %%
sys.path.append("..")

# %%
from src.load_data import load_tables

# %%
tables = load_tables()

# %% [markdown]
# ### ONLY TRIPS TABLE -- TO BE CLEANED

# %%
trips = tables['trips']

# %%
trips.shape
# Out:
# (20000, 15)

# %%
trips.dropna(inplace=True)

# %%
trips.shape
# Out:
# (16827, 15)

# %%
trips.isnull().sum()
# Out:
# trip_id                0
# rider_id               0
# driver_id              0
# pickup_location_id     0
# dropoff_location_id    0
# requested_at           0
# started_at             0
# completed_at           0
# status                 0
# distance_km            0
# duration_mins          0
# base_fare              0
# surge_multiplier       0
# total_fare             0
# payment_method         0
# dtype: int64

# %%
trips.duplicated().sum()
# Out:
# np.int64(0)

# %%
trips.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 16827 entries, 0 to 19998
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   trip_id              16827 non-null  int64
#  1   rider_id             16827 non-null  int64
#  2   driver_id            16827 non-null  int64
#  3   pickup_location_id   16827 non-null  int64
#  4   dropoff_location_id  16827 non-null  int64
#  5   requested_at         16827 non-null  str
#  6   started_at           16827 non-null  str
#  7   completed_at         16827 non-null  str
#  8   status               16827 non-null  str
#  9   distance_km          16827 non-null  float64
#  10  duration_mins        16827 non-null  int64
#  11  base_fare            16827 non-null  float64
#  12  surge_multiplier     16827 non-null  float64
#  13  total_fare           16827 non-null  float64
#  14  payment_method       16827 non-null  str
# dtypes: float64(4), int64(6), str(5)
# ...

# %%
trips.describe()
# Out:
#             trip_id     rider_id     driver_id  pickup_location_id  \
# count  16827.000000  16827.00000  16827.000000        16827.000000
# mean   10011.081714    808.85862    202.051524           20.014560
# std     5779.965539    459.31752    114.439893           11.957166
# min        1.000000      1.00000      1.000000            1.000000
# 25%     5016.500000    414.00000    102.000000            9.000000
# 50%    10022.000000    802.00000    207.000000           19.000000
# 75%    15025.500000   1228.00000    299.000000           31.000000
# max    19999.000000   1570.00000    400.000000           40.000000
#
#        dropoff_location_id   distance_km  duration_mins     base_fare  \
# count         16827.000000  16827.000000   16827.000000  16827.000000
# mean             20.012064     18.018348      31.371011     28.594679
# std              11.980879     11.375678      20.191828     15.877931
# min               1.000000      0.500000       3.000000      3.650000
# ...

# %%
trips.to_csv("../src/cleaned_trips.csv",index=False)
