# %%
import sys
sys.path.append("..")

# %%
from src.load_data import load_tables

# %%
tables = load_tables()

# %%
users = tables['users']
drivers = tables['drivers']
riders = tables['riders']
locations = tables['locations']
trips = tables['trips']
payments = tables['payments']
reviews = tables['reviews']
cancellations = tables['cancellations']

# %% [markdown]
# ## UNDERSTANDING THE DATA

# %% [markdown]
# ### USERS TABLE
# - Number of Rows : 2000
# - Number of Columns : 7
# - Missing Values : None
# - Duplicate Rows : None

# %%
users.shape
# Out:
# (2000, 7)

# %%
users.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      2000 non-null   int64
#  1   name         2000 non-null   str
#  2   email        2000 non-null   str
#  3   phone        2000 non-null   str
#  4   city         2000 non-null   str
#  5   date_joined  2000 non-null   str
#  6   is_driver    2000 non-null   int64
# dtypes: int64(2), str(5)
# memory usage: 109.5 KB

# %%
users.describe(include='all')
# Out:
#             user_id          name                  email            phone  \
# count   2000.000000          2000                   2000             2000
# unique          NaN          1764                   2000             2000
# top             NaN  Diane Hughes  david.white@gmail.com  +1-809-169-4853
# freq            NaN             3                      1                1
# mean    1000.500000           NaN                    NaN              NaN
# std      577.494589           NaN                    NaN              NaN
# min        1.000000           NaN                    NaN              NaN
# 25%      500.750000           NaN                    NaN              NaN
# 50%     1000.500000           NaN                    NaN              NaN
# 75%     1500.250000           NaN                    NaN              NaN
# max     2000.000000           NaN                    NaN              NaN
#
#            city date_joined  is_driver
# count      2000        2000  2000.0000
# ...

# %%
users.isnull().sum()
# Out:
# user_id        0
# name           0
# email          0
# phone          0
# city           0
# date_joined    0
# is_driver      0
# dtype: int64

# %%
users.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### DRIVERS TABLE
# - Number of Rows : 400
# - Number of Columns : 9
# - Missing Values : None
# - Duplicate Rows : None

# %%
drivers.shape
# Out:
# (400, 9)

# %%
drivers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   driver_id      400 non-null    int64
#  1   user_id        400 non-null    int64
#  2   vehicle_make   400 non-null    str
#  3   vehicle_model  400 non-null    str
#  4   vehicle_year   400 non-null    int64
#  5   license_plate  400 non-null    str
#  6   rating         400 non-null    float64
#  7   join_date      400 non-null    str
#  8   is_active      400 non-null    int64
# dtypes: float64(1), int64(4), str(4)
# memory usage: 28.3 KB

# %%
drivers.describe(include='all')
# Out:
#          driver_id     user_id vehicle_make vehicle_model  vehicle_year  \
# count   400.000000   400.00000          400           400    400.000000
# unique         NaN         NaN           10            50           NaN
# top            NaN         NaN       Nissan       Equinox           NaN
# freq           NaN         NaN           50            17           NaN
# mean    200.500000   995.78500          NaN           NaN   2017.530000
# std     115.614301   588.38962          NaN           NaN      3.521378
# min       1.000000     2.00000          NaN           NaN   2012.000000
# 25%     100.750000   468.50000          NaN           NaN   2014.000000
# 50%     200.500000  1017.00000          NaN           NaN   2018.000000
# 75%     300.250000  1497.50000          NaN           NaN   2020.250000
# max     400.000000  1999.00000          NaN           NaN   2023.000000
#
#        license_plate      rating   join_date   is_active
# ...

# %%
drivers.isnull().sum()
# Out:
# driver_id        0
# user_id          0
# vehicle_make     0
# vehicle_model    0
# vehicle_year     0
# license_plate    0
# rating           0
# join_date        0
# is_active        0
# dtype: int64

# %%
drivers.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### RIDERS TABLE
# - Number of Rows : 1600
# - Number of Columns : 5
# - Missing Values : None
# - Duplicate Rows : None

# %%
riders.shape
# Out:
# (1600, 5)

# %%
riders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rider_id     1600 non-null   int64
#  1   user_id      1600 non-null   int64
#  2   rating       1600 non-null   float64
#  3   total_trips  1600 non-null   int64
#  4   created_at   1600 non-null   str
# dtypes: float64(1), int64(3), str(1)
# memory usage: 62.6 KB

# %%
riders.describe(include='all')
# Out:
#           rider_id      user_id       rating  total_trips           created_at
# count   1600.00000  1600.000000  1600.000000  1600.000000                 1600
# unique         NaN          NaN          NaN          NaN                 1600
# top            NaN          NaN          NaN          NaN  2020-09-13 01:52:12
# freq           NaN          NaN          NaN          NaN                    1
# mean     800.50000  1001.678750     3.991137    10.516875                  NaN
# std      462.02453   574.919114     0.590380    17.336344                  NaN
# min        1.00000     1.000000     3.000000     0.000000                  NaN
# 25%      400.75000   515.500000     3.450000     1.000000                  NaN
# 50%      800.50000   998.500000     3.990000     3.000000                  NaN
# 75%     1200.25000  1501.250000     4.500000    13.000000                  NaN
# max     1600.00000  2000.000000     5.000000    94.000000                  NaN

# %%
riders.isnull().sum()
# Out:
# rider_id       0
# user_id        0
# rating         0
# total_trips    0
# created_at     0
# dtype: int64

# %%
riders.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### LOCATIONS TABLE
# - Number of rows : 40
# - Number of columns : 6
# - Missing Values : None
# - Duplicate rows : None

# %%
locations.shape
# Out:
# (40, 6)

# %%
locations.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   location_id  40 non-null     int64
#  1   zone_name    40 non-null     str
#  2   city         40 non-null     str
#  3   latitude     40 non-null     float64
#  4   longitude    40 non-null     float64
#  5   zone_type    40 non-null     str
# dtypes: float64(2), int64(1), str(3)
# memory usage: 2.0 KB

# %%
locations.describe(include='all')
# Out:
#         location_id     zone_name      city   latitude   longitude  \
# count     40.000000            40        40  40.000000   40.000000
# unique          NaN            40         4        NaN         NaN
# top             NaN  Times Square  New York        NaN         NaN
# freq            NaN             1        10        NaN         NaN
# mean      20.500000           NaN       NaN  36.606307  -93.843383
# std       11.690452           NaN       NaN   5.028859   16.302392
# min        1.000000           NaN       NaN  29.619700 -118.491000
# 25%       10.750000           NaN       NaN  32.919400 -101.262175
# 50%       20.500000           NaN       NaN  37.411050  -91.593100
# 75%       30.250000           NaN       NaN  41.055400  -84.193700
# max       40.000000           NaN       NaN  41.974200  -73.778100
#
#           zone_type
# count            40
# unique            4
# top     residential
# freq             16
# mean            NaN
# std             NaN
# ...

# %%
locations.isnull().sum()
# Out:
# location_id    0
# zone_name      0
# city           0
# latitude       0
# longitude      0
# zone_type      0
# dtype: int64

# %%
locations.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### TRIPS TABLE
# - Number of rows : 2000
# - Number of columns : 15
# - Missing values : Yes
# - Duplicate rows : None

# %%
trips.shape
# Out:
# (20000, 15)

# %%
trips.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   trip_id              20000 non-null  int64
#  1   rider_id             20000 non-null  int64
#  2   driver_id            20000 non-null  int64
#  3   pickup_location_id   20000 non-null  int64
#  4   dropoff_location_id  20000 non-null  int64
#  5   requested_at         20000 non-null  str
#  6   started_at           20000 non-null  str
#  7   completed_at         16827 non-null  str
#  8   status               20000 non-null  str
#  9   distance_km          20000 non-null  float64
#  10  duration_mins        20000 non-null  int64
#  11  base_fare            20000 non-null  float64
#  12  surge_multiplier     20000 non-null  float64
#  13  total_fare           20000 non-null  float64
#  14  payment_method       20000 non-null  str
# dtypes: float64(4), int64(6), str(5)
# ...

# %%
trips.describe(include='all')
# Out:
#              trip_id     rider_id     driver_id  pickup_location_id  \
# count   20000.000000  20000.00000  20000.000000        20000.000000
# unique           NaN          NaN           NaN                 NaN
# top              NaN          NaN           NaN                 NaN
# freq             NaN          NaN           NaN                 NaN
# mean    10000.500000    808.04035    201.431950           20.123100
# std      5773.647028    458.81708    114.642109           11.951405
# min         1.000000      1.00000      1.000000            1.000000
# 25%      5000.750000    414.00000    101.000000            9.000000
# 50%     10000.500000    801.00000    207.000000           20.000000
# 75%     15000.250000   1226.00000    298.000000           31.000000
# max     20000.000000   1571.00000    400.000000           40.000000
#
#         dropoff_location_id         requested_at           started_at  \
# count          20000.000000                20000                20000
# ...

# %%
trips.isnull().sum()
# Out:
# trip_id                   0
# rider_id                  0
# driver_id                 0
# pickup_location_id        0
# dropoff_location_id       0
# requested_at              0
# started_at                0
# completed_at           3173
# status                    0
# distance_km               0
# duration_mins             0
# base_fare                 0
# surge_multiplier          0
# total_fare                0
# payment_method            0
# dtype: int64

# %%
trips.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### PAYMENTS TABLE
# - Number of rows : 16827
# - Number of columns : 6
# - Missing Values : None
# - Duplicate Rows : None

# %%
payments.shape
# Out:
# (16827, 6)

# %%
payments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16827 entries, 0 to 16826
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   payment_id  16827 non-null  int64
#  1   trip_id     16827 non-null  int64
#  2   amount      16827 non-null  float64
#  3   method      16827 non-null  str
#  4   status      16827 non-null  str
#  5   paid_at     16827 non-null  str
# dtypes: float64(1), int64(2), str(3)
# memory usage: 788.9 KB

# %%
payments.describe(include='all')
# Out:
#           payment_id       trip_id        amount method   status  \
# count   16827.000000  16827.000000  16827.000000  16827    16827
# unique           NaN           NaN           NaN      3        3
# top              NaN           NaN           NaN   card  success
# freq             NaN           NaN           NaN   5700    16359
# mean     8414.000000  10011.081714     35.929751    NaN      NaN
# std      4857.680825   5779.965539     26.441414    NaN      NaN
# min         1.000000      1.000000      3.650000    NaN      NaN
# 25%      4207.500000   5016.500000     16.200000    NaN      NaN
# 50%      8414.000000  10022.000000     32.490000    NaN      NaN
# 75%     12620.500000  15025.500000     45.120000    NaN      NaN
# max     16827.000000  19999.000000    224.270000    NaN      NaN
#
#                     paid_at
# count                 16827
# unique                16825
# top     2023-03-28 20:53:07
# freq                      2
# mean                    NaN
# ...

# %%
payments.isnull().sum()
# Out:
# payment_id    0
# trip_id       0
# amount        0
# method        0
# status        0
# paid_at       0
# dtype: int64

# %%
payments.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### REVIEWS TABLE
# - Number of rows : 15136
# - Number of columns : 7
# - Missing values : Yes
# - Duplicate Rows : None

# %%
reviews.shape
# Out:
# (15136, 7)

# %%
reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15136 entries, 0 to 15135
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    15136 non-null  int64
#  1   trip_id      15136 non-null  int64
#  2   reviewer_id  15136 non-null  int64
#  3   reviewee_id  15136 non-null  int64
#  4   rating       15136 non-null  int64
#  5   comment      9216 non-null   str
#  6   reviewed_at  15136 non-null  str
# dtypes: int64(5), str(2)
# memory usage: 827.9 KB

# %%
reviews.describe(include='all')
# Out:
#            review_id       trip_id   reviewer_id   reviewee_id        rating  \
# count   15136.000000  15136.000000  15136.000000  15136.000000  15136.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     7568.500000  10016.379757   1009.110663    999.172569      3.654070
# std      4369.531172   5778.288510    576.700326    581.698296      0.869887
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%      3784.750000   5012.500000    510.000000    485.000000      3.000000
# 50%      7568.500000  10057.000000   1044.000000   1028.500000      4.000000
# 75%     11352.250000  15016.250000   1489.000000   1483.000000      4.000000
# max     15136.000000  19999.000000   2000.000000   2000.000000      5.000000
#
# ...

# %%
reviews.isnull().sum()
# Out:
# review_id         0
# trip_id           0
# reviewer_id       0
# reviewee_id       0
# rating            0
# comment        5920
# reviewed_at       0
# dtype: int64

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### CANCELLATIONS TABLE
# - Number of rows : 2966
# - Number of columns : 5
# - Missing Values : None
# - Duplicate rows : None

# %%
cancellations.shape
# Out:
# (2966, 5)

# %%
cancellations.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2966 entries, 0 to 2965
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cancel_id     2966 non-null   int64
#  1   trip_id       2966 non-null   int64
#  2   cancelled_by  2966 non-null   str
#  3   reason        2966 non-null   str
#  4   cancelled_at  2966 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 116.0 KB

# %%
cancellations.describe(include='all')
# Out:
#           cancel_id       trip_id cancelled_by              reason  \
# count   2966.000000   2966.000000         2966                2966
# unique          NaN           NaN            2                  14
# top             NaN           NaN        rider  personal emergency
# freq            NaN           NaN         2069                 396
# mean    1483.500000   9950.007417          NaN                 NaN
# std      856.354775   5734.265379          NaN                 NaN
# min        1.000000      2.000000          NaN                 NaN
# 25%      742.250000   4942.750000          NaN                 NaN
# 50%     1483.500000   9903.500000          NaN                 NaN
# 75%     2224.750000  14947.750000          NaN                 NaN
# max     2966.000000  19990.000000          NaN                 NaN
#
#                cancelled_at
# count                  2966
# unique                 2966
# top     2024-01-25 20:55:28
# freq                      1
# ...

# %%
cancellations.isnull().sum()
# Out:
# cancel_id       0
# trip_id         0
# cancelled_by    0
# reason          0
# cancelled_at    0
# dtype: int64

# %%
cancellations.duplicated().sum()
# Out:
# np.int64(0)
